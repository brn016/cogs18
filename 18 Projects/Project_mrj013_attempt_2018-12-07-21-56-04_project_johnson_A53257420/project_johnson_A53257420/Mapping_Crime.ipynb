# %% [markdown]
# This program will allow the user to view data using the folium package.
# The user can import data (violence data in this case). The program will
# analyze the data so that we can visualize the number of incidents on the
# a folium generated map. This test is conducted using a same portion of a
# much larger dataset.

# %%
#installing necessary packages
# !pip install twisted
# !pip install ipyleaflet
# !pip install folium
# !pip install pandas

# %%
import matplotlib.pyplot as plt
import pandas as pd
import folium
import time

# %%
#Importing data and converting dates and pulling day to analyze crimes on specific day -- sample code
gun_csv = pd.read_csv("guns_example.csv")
gun_csv["date"] = pd.to_datetime(gun_csv["date"])
gun_csv["day"] = gun_csv["date"].map(lambda x: x.day)

gun_csv
# Out:
#      Unnamed: 0  incident_id       date                 state  \
# 0             1       461105 2013-01-01          Pennsylvania
# 1             2       460726 2013-01-01            California
# 2             3       478855 2013-01-01                  Ohio
# 3             4       478925 2013-01-05              Colorado
# 4             5       478959 2013-01-07        North Carolina
# 5             6       478948 2013-01-07              Oklahoma
# 6             7       479363 2013-01-19            New Mexico
# 7             8       479374 2013-01-21             Louisiana
# 8             9       479389 2013-01-21            California
# 9            10       492151 2013-01-23              Maryland
# 10           11       491674 2013-01-23             Tennessee
# 11           12       479413 2013-01-25              Missouri
# 12           13       479561 2013-01-26             Louisiana
# 13           14       479554 2013-01-26  District of Columbia
# 14           15       479460 2013-01-26                  Ohio
# 15           16       479573 2013-02-02             Tennessee
# 16           17       479580 2013-02-03            California
# 17           18       479592 2013-02-07              Illinois
# 18           19       479603 2013-02-09             Louisiana
# 19           20       480311 2013-02-11            California
# 20           21       480327 2013-02-11              Delaware
# 21           22       480344 2013-02-12                  Utah
# 22           23       480358 2013-02-19            California
# 23           24       480383 2013-02-21              Oklahoma
# 24           25       480401 2013-02-22              Michigan
# 25           26       480407 2013-02-23            California
# 26           27       480443 2013-02-24               Georgia
# 27           28       481186 2013-03-02             Louisiana
# 28           29       481198 2013-03-03               Georgia
# 29           30       481208 2013-03-03              Michigan
# ..          ...          ...        ...                   ...
# 167         168       486316 2013-05-13                  Ohio
# 168         169      1007785 2013-05-14            New Jersey
# 169         170       486327 2013-05-15              Michigan
# 170         171       486334 2013-05-16          Pennsylvania
# 171         172       873575 2013-05-18              New York
# 172         173       486611 2013-05-18              Virginia
# 173         174       486586 2013-05-19             Tennessee
# 174         175       486605 2013-05-19              Michigan
# 175         176       486617 2013-05-20              Illinois
# 176         177       486623 2013-05-23             Tennessee
# 177         178       486971 2013-05-24            California
# 178         179       486977 2013-05-25              Michigan
# 179         180       486998 2013-05-25              Virginia
# 180         181       487052 2013-05-28             Tennessee
# 181         182       487082 2013-05-29              Illinois
# 182         183       487088 2013-05-31               Georgia
# 183         184       487261 2013-06-01             Wisconsin
# 184         185       489314 2013-06-01            California
# 185         186       487266 2013-06-02               Indiana
# 186         187       487271 2013-06-02              Virginia
# 187         188       487435 2013-06-02               Georgia
# 188         189       489581 2013-06-07            California
# 189         190       487645 2013-06-09          Pennsylvania
# 190         191       487659 2013-06-10              Missouri
# 191         192       487670 2013-06-10              Illinois
# 192         193       487715 2013-06-14        North Carolina
# 193         194       488992 2013-06-15          Rhode Island
# 194         195       487833 2013-06-15             Tennessee
# 195         196       487891 2013-06-15                 Texas
# 196         197       488134 2013-06-16              Illinois
#
#                  city                                            address  \
# 0          Mckeesport          1506 Versailles Avenue and Coursin Street
# 1           Hawthorne                       13500 block of Cerise Avenue
# 2              Lorain                              1776 East 28th Street
# 3              Aurora                   16000 block of East Ithaca Place
# 4          Greensboro                          307 Mourning Dove Terrace
# 5               Tulsa                         6000 block of South Owasso
# 6         Albuquerque                                     2806 Long Lane
# 7         New Orleans  LaSalle Street and Martin Luther King Jr. Boul...
# 8           Brentwood                         1100 block of Breton Drive
# 9           Baltimore                       1500 block of W. Fayette St.
# 10        Chattanooga                                     1501 Dodds Ave
# 11        Saint Louis                W Florissant Ave and Riverview Blvd
# 12          Charenton                       1000 block of Flat Town Road
# 13         Washington                        2403 Benning Road Northeast
# 14        Springfield                               601 West Main Street
# 15            Memphis                                  2514 Mount Moriah
# 16      Yuba (county)                        5800 block of Poplar Avenue
# 17            Chicago                     2500 block of East 75th Street
# 18        New Orleans                        400 block of Bourbon Street
# 19            Vallejo                       800 block of Humboldt Street
# 20         Wilmington                              500 North King Street
# 21            Midvale              8286 Adams Street and 450 West Street
# 22    Orange (county)                                     Katella Avenue
# 23              Tulsa               1200 block of North 89th East Avenue
# 24       Grand Rapids                            1447 Grandville Ave. SW
# 25          Lancaster                      43145 Business Center Parkway
# 26              Macon              2800 block of Mercer University Drive
# 27         Shreveport                 7000 block of Burlingame Boulevard
# 28           Moultrie                        224 Second Street Northwest
# 29   Saginaw (county)                                     4030 Dixie Hwy
# ..                ...                                                ...
# 167        Cincinnati                                       Delaware Ave
# 168           Delanco                               9000 block of Carlin
# 169           Detroit                       2600 block of Daggett Street
# 170      Philadelphia                     Sutphin Blvd and Rockaway Blvd
# 171           Jamaica                                                NaN
# 172          Victoria                                                NaN
# 173           Memphis                                                NaN
# 174           Detroit                                                NaN
# 175           Chicago                                                NaN
# 176      Bean Station                                                NaN
# 177       Bakersfield                                                NaN
# 178             Flint                                                NaN
# 179           Hampton                                                NaN
# 180           Memphis                                                NaN
# 181           Chicago                                                NaN
# 182           Atlanta                                                NaN
# 183         Milwaukee                                                NaN
# 184           Vallejo                                                NaN
# 185      Indianapolis                                                NaN
# 186    Virginia Beach                                                NaN
# 187          Lagrange                                                NaN
# 188      Santa Monica                                                NaN
# 189              York                                                NaN
# 190       Saint Louis                                                NaN
# 191           Chicago                                                NaN
# 192        High Point                                                NaN
# 193        Providence                                                NaN
# 194         Nashville                                                NaN
# 195           Houston                                                NaN
# 196           Chicago                                                NaN
#
#      n_killed  n_injured                           incident_characteristics  \
# 0         4.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 1        10.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 2        10.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 3         6.0        0.0  Shot - Dead (murder, accidental, suicide)||Off...
# 4        10.0        2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 5         5.0        0.0  Shot - Dead (murder, accidental, suicide)||Hom...
# 6         2.0        0.0  Shot - Dead (murder, accidental, suicide)||Mas...
# 7         7.0        5.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 8        12.0        4.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 9        14.0        6.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 10       12.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 11       10.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 12       12.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 13       10.0        5.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 14        8.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 15        6.0        5.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 16        2.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 17       12.0        4.0  Shot - Wounded/Injured||Drive-by (car to stree...
# 18        5.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 19        5.0        4.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 20        8.0        2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 21        6.0        1.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 22       11.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 23        6.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 24        8.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 25        4.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 26        6.0        8.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 27        6.0        3.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 28       10.0        2.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 29       12.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# ..        ...        ...                                                ...
# 167       3.0        2.0  Shot - Wounded/Injured||Officer Involved Incid...
# 168      14.0        4.0  Shot - Wounded/Injured||Shot - Dead (murder, a...
# 169       2.0        4.0  Shot - Wounded/Injured||Mass Shooting (4+ vict...
# 170      15.0        0.0  Shot - Dead (murder, accidental, suicide)||Gan...
# 171       NaN        NaN                                                NaN
# 172       NaN        NaN                                                NaN
# 173       NaN        NaN                                                NaN
# 174       NaN        NaN                                                NaN
# 175       NaN        NaN                                                NaN
# 176       NaN        NaN                                                NaN
# 177       NaN        NaN                                                NaN
# 178       NaN        NaN                                                NaN
# 179       NaN        NaN                                                NaN
# 180       NaN        NaN                                                NaN
# 181       NaN        NaN                                                NaN
# 182       NaN        NaN                                                NaN
# 183       NaN        NaN                                                NaN
# 184       NaN        NaN                                                NaN
# 185       NaN        NaN                                                NaN
# 186       NaN        NaN                                                NaN
# 187       NaN        NaN                                                NaN
# 188       NaN        NaN                                                NaN
# 189       NaN        NaN                                                NaN
# 190       NaN        NaN                                                NaN
# 191       NaN        NaN                                                NaN
# 192       NaN        NaN                                                NaN
# 193       NaN        NaN                                                NaN
# 194       NaN        NaN                                                NaN
# 195       NaN        NaN                                                NaN
# 196       NaN        NaN                                                NaN
#
#      lat_incident  lng_incident  day
# 0         40.3467      -79.8559    1
# 1         33.9090     -118.3330    1
# 2         41.4455      -82.1377    1
# 3         39.6518     -104.8020    5
# 4         36.1140      -79.9569    7
# 5         36.2405      -95.9768    7
# 6         34.9791     -106.7160   19
# 7         29.9435      -90.0836   21
# 8         37.9656     -121.7180   21
# 9         39.2899      -76.6412   23
# 10        35.0221      -85.2697   23
# 11        38.7067      -90.2494   25
# 12        29.8816      -91.5251   26
# 13        38.8978      -76.9717   26
# 14        39.9252      -83.8218   26
# 15        35.0803      -89.8871    2
# 16        39.1236     -121.5830    3
# 17        41.7592      -87.5628    7
# 18        29.9563      -90.0676    9
# 19        38.1072     -122.2280   11
# 20        39.7407      -75.5499   11
# 21        40.6008     -111.9030   12
# 22        33.8031     -117.9430   19
# 23        36.1722      -95.8778   21
# 24        42.9371      -85.6853   22
# 25        34.6666     -118.1310   23
# 26        32.8260      -83.6704   24
# 27        32.4420      -93.7726    2
# 28        31.1824      -83.7912    3
# 29        43.3944      -83.9082    3
# ..            ...           ...  ...
# 167       40.0521      -74.9578   13
# 168       42.3613      -83.1787   14
# 169       39.9204      -75.2296   15
# 170       40.6730      -73.7881   16
# 171           NaN           NaN   18
# 172           NaN           NaN   18
# 173           NaN           NaN   19
# 174           NaN           NaN   19
# 175           NaN           NaN   20
# 176           NaN           NaN   23
# 177           NaN           NaN   24
# 178           NaN           NaN   25
# 179           NaN           NaN   25
# 180           NaN           NaN   28
# 181           NaN           NaN   29
# 182           NaN           NaN   31
# 183           NaN           NaN    1
# 184           NaN           NaN    1
# 185           NaN           NaN    2
# 186           NaN           NaN    2
# 187           NaN           NaN    2
# 188           NaN           NaN    7
# 189           NaN           NaN    9
# 190           NaN           NaN   10
# 191           NaN           NaN   10
# 192           NaN           NaN   14
# 193           NaN           NaN   15
# 194           NaN           NaN   15
# 195           NaN           NaN   15
# 196           NaN           NaN   16
#
# [197 rows x 12 columns]

# %%
#template to match if user want to add statistics
template = pd.read_csv('template.csv')
print("Please ensure that data matches this template!")
template
# Out:
# Please ensure that data matches this template!
#       id  incident_id     date                 state              city  \
# 0      1       461105   1/1/13          Pennsylvania        Mckeesport
# 1      2       460726   1/1/13            California         Hawthorne
# 2      3       478855   1/1/13                  Ohio            Lorain
# 3      4       478925   1/5/13              Colorado            Aurora
# 4      5       478959   1/7/13        North Carolina        Greensboro
# 5      6       478948   1/7/13              Oklahoma             Tulsa
# 6      7       479363  1/19/13            New Mexico       Albuquerque
# 7      8       479374  1/21/13             Louisiana       New Orleans
# 8      9       479389  1/21/13            California         Brentwood
# 9     10       492151  1/23/13              Maryland         Baltimore
# 10    11       491674  1/23/13             Tennessee       Chattanooga
# 11    12       479413  1/25/13              Missouri       Saint Louis
# 12    13       479561  1/26/13             Louisiana         Charenton
# 13    14       479554  1/26/13  District of Columbia        Washington
# 14    15       479460  1/26/13                  Ohio       Springfield
# 15    16       479573   2/2/13             Tennessee           Memphis
# 16    17       479580   2/3/13            California     Yuba (county)
# 17    18       479592   2/7/13              Illinois           Chicago
# 18    19       479603   2/9/13             Louisiana       New Orleans
# 19    20       480311  2/11/13            California           Vallejo
# 20    21       480327  2/11/13              Delaware        Wilmington
# 21    22       480344  2/12/13                  Utah           Midvale
# 22    23       480358  2/19/13            California   Orange (county)
# 23    24       480383  2/21/13              Oklahoma             Tulsa
# 24    25       480401  2/22/13              Michigan      Grand Rapids
# 25    26       480407  2/23/13            California         Lancaster
# 26    27       480443  2/24/13               Georgia             Macon
# 27    28       481186   3/2/13             Louisiana        Shreveport
# 28    29       481198   3/3/13               Georgia          Moultrie
# 29    30       481208   3/3/13              Michigan  Saginaw (county)
# ..   ...          ...      ...                   ...               ...
# 74    75       486316  5/13/13                  Ohio        Cincinnati
# 75    76      1007785  5/14/13            New Jersey           Delanco
# 76    77       486327  5/15/13              Michigan           Detroit
# 77    78       486334  5/16/13          Pennsylvania      Philadelphia
# 78    79       873575  5/18/13              New York           Jamaica
# 79    80       486611  5/18/13              Virginia          Victoria
# 80    81       486586  5/19/13             Tennessee           Memphis
# 81    82       486605  5/19/13              Michigan           Detroit
# 82    83       486617  5/20/13              Illinois           Chicago
# 83    84       486623  5/23/13             Tennessee      Bean Station
# 84    85       486971  5/24/13            California       Bakersfield
# 85    86       486977  5/25/13              Michigan             Flint
# 86    87       486998  5/25/13              Virginia           Hampton
# 87    88       487052  5/28/13             Tennessee           Memphis
# 88    89       487082  5/29/13              Illinois           Chicago
# 89    90       487088  5/31/13               Georgia           Atlanta
# 90    91       487261   6/1/13             Wisconsin         Milwaukee
# 91    92       489314   6/1/13            California           Vallejo
# 92    93       487266   6/2/13               Indiana      Indianapolis
# 93    94       487271   6/2/13              Virginia    Virginia Beach
# 94    95       487435   6/2/13               Georgia          Lagrange
# 95    96       489581   6/7/13            California      Santa Monica
# 96    97       487645   6/9/13          Pennsylvania              York
# 97    98       487659  6/10/13              Missouri       Saint Louis
# 98    99       487670  6/10/13              Illinois           Chicago
# 99   100       487715  6/14/13        North Carolina        High Point
# 100  101       488992  6/15/13          Rhode Island        Providence
# 101  102       487833  6/15/13             Tennessee         Nashville
# 102  103       487891  6/15/13                 Texas           Houston
# 103  104       488134  6/16/13              Illinois           Chicago
#
#                                                address  n_killed  n_injured  \
# 0            1506 Versailles Avenue and Coursin Street         0          4
# 1                         13500 block of Cerise Avenue         1          3
# 2                                1776 East 28th Street         1          3
# 3                     16000 block of East Ithaca Place         4          0
# 4                            307 Mourning Dove Terrace         2          2
# 5                           6000 block of South Owasso         4          0
# 6                                       2806 Long Lane         5          0
# 7    LaSalle Street and Martin Luther King Jr. Boul...         0          5
# 8                           1100 block of Breton Drive         0          4
# 9                         1500 block of W. Fayette St.         1          6
# 10                                      1501 Dodds Ave         1          3
# 11                 W Florissant Ave and Riverview Blvd         1          3
# 12                        1000 block of Flat Town Road         2          3
# 13                         2403 Benning Road Northeast         0          5
# 14                                601 West Main Street         1          3
# 15                                   2514 Mount Moriah         0          5
# 16                         5800 block of Poplar Avenue         1          3
# 17                      2500 block of East 75th Street         0          4
# 18                         400 block of Bourbon Street         0          4
# 19                        800 block of Humboldt Street         1          4
# 20                               500 North King Street         3          2
# 21               8286 Adams Street and 450 West Street         4          1
# 22                                      Katella Avenue         4          3
# 23                1200 block of North 89th East Avenue         1          3
# 24                             1447 Grandville Ave. SW         0          4
# 25                       43145 Business Center Parkway         0          4
# 26               2800 block of Mercer University Drive         0          8
# 27                  7000 block of Burlingame Boulevard         1          3
# 28                         224 Second Street Northwest         2          2
# 29                                      4030 Dixie Hwy         0          4
# ..                                                 ...       ...        ...
# 74                                      Kings Run Road         0          4
# 75                                        Delaware Ave         0          2
# 76                                9000 block of Carlin         1          4
# 77                        2600 block of Daggett Street         0          4
# 78                      Sutphin Blvd and Rockaway Blvd         1          0
# 79                                2073 Pleasant Oak Rd         0          4
# 80                                     2281 Ketchum Rd         2          2
# 81                                                 NaN         0          4
# 82                      5200 block of West Iowa Street         0          4
# 83                                    1034 Main Street         2          2
# 84                       3700 block of Columbus Street         2          2
# 85                              1100 block of Paterson         1          3
# 86                        1900 block of Coliseum Drive         1          4
# 87                                  2850 Brewer Avenue         1          3
# 88                                                 NaN         0          4
# 89                           1000 block of Fair Street         0          4
# 90                                 4126 N Teutonia Ave         0          4
# 91                         1st block of Linfield Drive         2          2
# 92                               1913 East 46th Street         0          4
# 93                         4000 block of Roebling Lane         0          7
# 94                                        Union Street         0          7
# 95                                  2036 Yorkshire Ave         6          1
# 96                   600 block of West Princess Street         0          4
# 97                          4700 block of Highland Ave         0          6
# 98                 5700 block of South Sangamon Street         1          4
# 99                                  2201 Little Avenue         0          5
# 100                                   256 Hartford Ave         1          3
# 101                                 135 Brinkhaven Ave         0          4
# 102                                     9780 Bissonnet         1          3
# 103                       900block of East 79th Street         1          3
#
#                               incident_characteristics  lat_incident  \
# 0    Shot - Wounded/Injured||Mass Shooting (4+ vict...       40.3467
# 1    Shot - Wounded/Injured||Shot - Dead (murder, a...       33.9090
# 2    Shot - Wounded/Injured||Shot - Dead (murder, a...       41.4455
# 3    Shot - Dead (murder, accidental, suicide)||Off...       39.6518
# 4    Shot - Wounded/Injured||Shot - Dead (murder, a...       36.1140
# 5    Shot - Dead (murder, accidental, suicide)||Hom...       36.2405
# 6    Shot - Dead (murder, accidental, suicide)||Mas...       34.9791
# 7    Shot - Wounded/Injured||Drive-by (car to stree...       29.9435
# 8    Shot - Wounded/Injured||Drive-by (car to stree...       37.9656
# 9    Shot - Wounded/Injured||Shot - Dead (murder, a...       39.2899
# 10   Shot - Wounded/Injured||Shot - Dead (murder, a...       35.0221
# 11   Shot - Wounded/Injured||Shot - Dead (murder, a...       38.7067
# 12   Shot - Wounded/Injured||Shot - Dead (murder, a...       29.8816
# 13   Shot - Wounded/Injured||Mass Shooting (4+ vict...       38.8978
# 14   Shot - Wounded/Injured||Shot - Dead (murder, a...       39.9252
# 15   Shot - Wounded/Injured||Mass Shooting (4+ vict...       35.0803
# 16   Shot - Wounded/Injured||Shot - Dead (murder, a...       39.1236
# 17   Shot - Wounded/Injured||Drive-by (car to stree...       41.7592
# 18   Shot - Wounded/Injured||Mass Shooting (4+ vict...       29.9563
# 19   Shot - Wounded/Injured||Shot - Dead (murder, a...       38.1072
# 20   Shot - Wounded/Injured||Shot - Dead (murder, a...       39.7407
# 21   Shot - Wounded/Injured||Shot - Dead (murder, a...       40.6008
# 22   Shot - Wounded/Injured||Shot - Dead (murder, a...       33.8031
# 23   Shot - Wounded/Injured||Shot - Dead (murder, a...       36.1722
# 24   Shot - Wounded/Injured||Mass Shooting (4+ vict...       42.9371
# 25   Shot - Wounded/Injured||Mass Shooting (4+ vict...       34.6666
# 26   Shot - Wounded/Injured||Mass Shooting (4+ vict...       32.8260
# 27   Shot - Wounded/Injured||Shot - Dead (murder, a...       32.4420
# 28   Shot - Wounded/Injured||Shot - Dead (murder, a...       31.1824
# 29   Shot - Wounded/Injured||Mass Shooting (4+ vict...       43.3944
# ..                                                 ...           ...
# 74   Shot - Wounded/Injured||Mass Shooting (4+ vict...       39.1788
# 75   Shot - Wounded/Injured||Officer Involved Incid...       40.0521
# 76   Shot - Wounded/Injured||Shot - Dead (murder, a...       42.3613
# 77   Shot - Wounded/Injured||Mass Shooting (4+ vict...       39.9204
# 78   Shot - Dead (murder, accidental, suicide)||Gan...       40.6730
# 79   Shot - Wounded/Injured||Drive-by (car to stree...       37.0177
# 80   Shot - Wounded/Injured||Shot - Dead (murder, a...       35.0790
# 81   Shot - Wounded/Injured||Drive-by (car to stree...       42.3481
# 82   Shot - Wounded/Injured||Drive-by (car to stree...       41.8968
# 83   Shot - Wounded/Injured||Shot - Dead (murder, a...       36.3474
# 84   Shot - Wounded/Injured||Shot - Dead (murder, a...       35.3998
# 85   Shot - Wounded/Injured||Shot - Dead (murder, a...       43.0340
# 86   Shot - Wounded/Injured||Shot - Dead (murder, a...       37.0377
# 87   Shot - Wounded/Injured||Shot - Dead (murder, a...       35.0848
# 88   Shot - Wounded/Injured||Drive-by (car to stree...       41.8859
# 89   Shot - Wounded/Injured||Mass Shooting (4+ vict...       33.7490
# 90   Shot - Wounded/Injured||Mass Shooting (4+ vict...       43.0920
# 91   Shot - Wounded/Injured||Shot - Dead (murder, a...       38.1472
# 92   Shot - Wounded/Injured||Mass Shooting (4+ vict...       39.8401
# 93   Shot - Wounded/Injured||Mass Shooting (4+ vict...       36.8459
# 94   Shot - Wounded/Injured||Mass Shooting (4+ vict...       33.0354
# 95   Shot - Wounded/Injured||Shot - Dead (murder, a...       34.0260
# 96   Shot - Wounded/Injured||Mass Shooting (4+ vict...       39.9550
# 97   Shot - Wounded/Injured||Drive-by (car to stree...       38.6647
# 98   Shot - Wounded/Injured||Shot - Dead (murder, a...       41.7904
# 99   Shot - Wounded/Injured||Drive-by (car to stree...       35.9689
# 100  Shot - Wounded/Injured||Shot - Dead (murder, a...       41.8173
# 101  Shot - Wounded/Injured||Mass Shooting (4+ vict...       36.1646
# 102  Shot - Wounded/Injured||Shot - Dead (murder, a...       29.6754
# 103  Shot - Wounded/Injured||Shot - Dead (murder, a...       41.7513
#
#      lng_incident
# 0        -79.8559
# 1       -118.3330
# 2        -82.1377
# 3       -104.8020
# 4        -79.9569
# 5        -95.9768
# 6       -106.7160
# 7        -90.0836
# 8       -121.7180
# 9        -76.6412
# 10       -85.2697
# 11       -90.2494
# 12       -91.5251
# 13       -76.9717
# 14       -83.8218
# 15       -89.8871
# 16      -121.5830
# 17       -87.5628
# 18       -90.0676
# 19      -122.2280
# 20       -75.5499
# 21      -111.9030
# 22      -117.9430
# 23       -95.8778
# 24       -85.6853
# 25      -118.1310
# 26       -83.6704
# 27       -93.7726
# 28       -83.7912
# 29       -83.9082
# ..            ...
# 74       -84.5124
# 75       -74.9578
# 76       -83.1787
# 77       -75.2296
# 78       -73.7881
# 79       -78.1562
# 80       -89.9880
# 81       -83.0613
# 82       -87.7556
# 83       -83.2849
# 84      -118.9520
# 85       -83.7182
# 86       -76.3859
# 87       -89.9678
# 88       -87.6251
# 89       -84.4211
# 90       -87.9400
# 91      -122.2400
# 92       -86.1289
# 93       -76.1171
# 94       -85.0244
# 95      -118.4610
# 96       -76.7412
# 97       -90.2506
# 98       -87.6490
# 99       -79.9787
# 100      -71.4516
# 101      -86.7771
# 102      -95.5499
# 103      -87.6027
#
# [104 rows x 11 columns]

# %%
#Loading and viewing data -- confirming it matches template 
def load_data_template():
    print("Please ensure your data matches template format")
    
    #Cue user to check template to compare data loaded using panda
    confirm = input("Does your data match the template folder? (Y/N): ")
    if confirm == "Y":
        True
    elif confirm == "N":
        print("Please review the template and make changes before visualization attempt")
    else:
        print("Invalid reponse. Please review template. Program will attempt mapping.")

# %%
def sum_violence_day(analyze_day):
    
    #load_data_template()
    #Uncomment above line if you want to interact with program. 
    #Was told that admins didn't want to have to input value during grading. 
    #Program will run without this check just fine.
    
    #sums the violence for a particular day across the US
    locations = gun_csv.groupby("state").first()    
    locations = locations.loc[:, ["lat_incident","lng_incident","city"]]
    sum_day = gun_csv[gun_csv["day"] == analyze_day]
    
    #counts incidents on specific day and classifies it to location
    incidents_total =  sum_day.groupby("state").count()
    incidents_total = incidents_total.iloc[:,[0]]
    incidents_total.columns= ["Incidents Today"]
    
    #Return number of cases at location
    no_cases = incidents_total.join(locations)
    return no_cases

# %%
def visual_incidents(no_cases):
    #making US map and adding points to plot violence
    folium_map = folium.Map(location=[40, -97],
                            zoom_start=4,
                            tiles='Mapbox Control Room')
    
    #point map creation and marking
    for x, row in no_cases.iterrows():
        gun_violence = (row["Incidents Today"]) #total violence
        
        #Elements of the interact ive map
        popup_text = "{}<br> total incidents: {}"        
        popup_text = popup_text.format(row["city"], gun_violence)
        
        radius = gun_violence*10
        
        # choose the color of the marker
        if gun_violence>0:
            color="#E37222"
        else:           
            color="#0A8A9F"
        
        # add marker to the map
        folium.CircleMarker(location=(row["lat_incident"],
                                      row["lng_incident"]),
                            radius=radius,
                            color=color,
                            popup=popup_text,
                            fill=True).add_to(folium_map)
    return folium_map

# %%
#Run program to collect analyzed data
gun_violence = sum_violence_day(10)

# %%
#Visualize data in map
gun_violence
visual_incidents(gun_violence)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
'''Testing functions'''
# Out:
# 'Testing functions'

# %%
#from functions import load_data_template, sum_violence_day, visual_incidents
#import necessary modules
import matplotlib.pyplot as plt
import pandas as pd
import folium

def test_load_data_template():
    #This is an input check function, is for user reference. 
    assert load_data_template() == None
    
def test_sum_violence_day(day):
    #input must be an integer to represent a day of the month
    assert isinstance(day, int)
    assert day <= 31
    
def test_visual_incidents(incidents):
    #visual_incidents takes return from sum_violence_day and must be integer (number of crimes)
    assert isinstance(incidents, int)
    assert incidents >= 0

# %%
#data to use for test
gun_csv = pd.read_csv("guns_example.csv")
gun_csv["date"] = pd.to_datetime(gun_csv["date"])
gun_csv["day"] = gun_csv["date"].map(lambda x: x.day)
template = pd.read_csv('template.csv')

# %%
#This should fail if any input. It is a check reference function. 
try:
    test_load_data_template(10)
except TypeError:
    print("Error caught")
# Out:
# Error caught

# %%
#Intentional testing, will result in error
try: 
    test_sum_violence_day("Y")
except AssertionError:
    print("Error caught")
# Out:
# Error caught

# %%
test_sum_violence_day(10)

# %%
#Intentional testing, will result in error
try:
    test_visual_incidents(-3)
except AssertionError:
    print("Error caught")
# Out:
# Error caught

# %%
test_visual_incidents(500)
