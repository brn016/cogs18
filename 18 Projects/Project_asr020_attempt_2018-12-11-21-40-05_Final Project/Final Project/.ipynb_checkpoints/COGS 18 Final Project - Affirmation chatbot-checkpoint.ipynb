# %% [markdown]
# ### Project Description:
#
# This project is an Affirmation Chatbot that takes a sad, negative, or harmful input like "I feel hopeless" and  returns a random phrase and picture to make the user feel better! The use of this chatbot is to help you feel a bit  better through positive phrases and affirmations as well as adorable pictures that motivate you to be happy.
#
#     - Please keep in mind this is a simple chatbot that has a limited range of communication with the user.

# %% [markdown]
# Run this to use affirmation_chatbot:

# %%
from my_module.chatbot import *

# %% [markdown]
# ## Talk to my chatbot!

# %%
affirmation_chatbot()
# Out:
# 		 Hello Sunshine! Welcome to Affirmation Chatbot!
#
#         Please Read the following line out loud to continue: 'I love myself'
#
#         	....Tricked you! I can't hear anything you say haha.
#
#         One way to feel good about yourself is to LOVE yourself... to take care of yourself' - G.H.
#         -------------------------------------------------------------------------------------------------------------
#         - To talk with Affirmation Chatbot: use plain english with either upper/lower case letters and punctuation
#         - To end the chat, enter: awesome
# Cool Person input :	hey
# OUTPUT: Hey! What's up?
# Cool Person input :	im sad
# OUTPUT: You are more than capable of accomplishing your dreams.
# Cool Person input :	im a loser
# OUTPUT: You're not a loser you're the coolest person i've ever met!
# Cool Person input :	suicide
# OUTPUT: I believe in you! Don't give up!
# Cool Person input :	awesome
# OUTPUT: Heck yea you are! Thanks for chatting <3
